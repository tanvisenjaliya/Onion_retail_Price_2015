# %% [markdown]
# # Data analysis of onion retail prices from Govt of India data home page

# %%
import pandas as pd

# %%
onion = pd.read_csv(r"C:\Users\ta20111785\Extras\projects\Onion_retail_prices\daily_retail_price_Onion-upto_apr_2015.csv")

# %%
onion
# Out:
#             Date      Centre_Name Commodity_Name  Price
# 0       25-11-97            DELHI          Onion    8.0
# 1       25-11-97           SHIMLA          Onion    7.0
# 2       25-11-97          LUCKNOW          Onion    5.0
# 3       25-11-97        AHMEDABAD          Onion    6.0
# 4       25-11-97           BHOPAL          Onion    8.0
# 5       25-11-97           MUMBAI          Onion    7.0
# 6       25-11-97           JAIPUR          Onion    6.0
# 7       25-11-97            PATNA          Onion    NaN
# 8       25-11-97     BHUBANESHWAR          Onion    9.0
# 9       25-11-97          KOLKATA          Onion   11.0
# 10      25-11-97         GUWAHATI          Onion    8.0
# 11      25-11-97         SHILLONG          Onion    9.0
# 12      25-11-97           AIZWAL          Onion    9.0
# 13      25-11-97         AGARTALA          Onion    9.0
# 14      25-11-97        BENGALURU          Onion    6.0
# 15      25-11-97          T.PURAM          Onion    6.5
# ...

# %%
onion.head(5)
# Out:
#        Date Centre_Name Commodity_Name  Price
# 0  25-11-97       DELHI          Onion    8.0
# 1  25-11-97      SHIMLA          Onion    7.0
# 2  25-11-97     LUCKNOW          Onion    5.0
# 3  25-11-97   AHMEDABAD          Onion    6.0
# 4  25-11-97      BHOPAL          Onion    8.0

# %%
onion.tail(5)
# Out:
#             Date      Centre_Name Commodity_Name  Price
# 127906  28-04-15         DINDIGUL          Onion   18.0
# 127907  28-04-15  THIRUCHIRAPALLI          Onion   18.0
# 127908  28-04-15       COIMBATORE          Onion   18.0
# 127909  28-04-15      TIRUNELVELI          Onion   18.0
# 127910  28-04-15        HYDERABAD          Onion   22.0

# %%
onion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127911 entries, 0 to 127910
# Data columns (total 4 columns):
# Date              127911 non-null object
# Centre_Name       127911 non-null object
# Commodity_Name    127911 non-null object
# Price             115991 non-null float64
# dtypes: float64(1), object(3)
# memory usage: 3.9+ MB

# %%
onion.shape
# Out:
# (127911, 4)

# %%
onion.ndim
# Out:
# 2

# %%
onion1 =onion.drop_duplicates()

# %%
onion1
# Out:
#             Date      Centre_Name Commodity_Name  Price
# 0       25-11-97            DELHI          Onion    8.0
# 1       25-11-97           SHIMLA          Onion    7.0
# 2       25-11-97          LUCKNOW          Onion    5.0
# 3       25-11-97        AHMEDABAD          Onion    6.0
# 4       25-11-97           BHOPAL          Onion    8.0
# 5       25-11-97           MUMBAI          Onion    7.0
# 6       25-11-97           JAIPUR          Onion    6.0
# 7       25-11-97            PATNA          Onion    NaN
# 8       25-11-97     BHUBANESHWAR          Onion    9.0
# 9       25-11-97          KOLKATA          Onion   11.0
# 10      25-11-97         GUWAHATI          Onion    8.0
# 11      25-11-97         SHILLONG          Onion    9.0
# 12      25-11-97           AIZWAL          Onion    9.0
# 13      25-11-97         AGARTALA          Onion    9.0
# 14      25-11-97        BENGALURU          Onion    6.0
# 15      25-11-97          T.PURAM          Onion    6.5
# ...

# %%
onion1.count()
# Out:
# Date              127911
# Centre_Name       127911
# Commodity_Name    127911
# Price             115991
# dtype: int64

# %%
print(onion1.isnull().sum())
# Out:
# Date                  0
# Centre_Name           0
# Commodity_Name        0
# Price             11920
# dtype: int64

# %%
# To find the correlation among 
# the columns using pearson method 
onion.corr(method ='pearson')
# Out:
#        Price
# Price    1.0

# %%
# To find the correlation among 
# the columns using kendall method 
onion.corr(method ='kendall')
# Out:
#        Price
# Price    1.0

# %%
onion1[['Date','Centre_Name','Price']].plot.box()

# %%
onion1[['Price']].plot.hist(bins = 20, title = 'Purchases Quantity Distribution')

# %%
onion1.groupby(['Centre_Name']).sum()
# Out:
#                     Price
# Centre_Name
# AGARTALA         68653.40
# AGRA             20412.00
# AHMEDABAD        47423.55
# AIZWAL           80019.50
# AMRITSAR         31405.00
# BATHINDA         14589.00
# BENGALURU        47089.80
# BHAGALPUR        18581.00
# BHOPAL           35721.50
# BHUBANESHWAR     53157.00
# CHANDIGARH       28548.00
# CHENNAI          49425.25
# COIMBATORE        3550.00
# CUTTACK          21684.00
# DEHRADUN         38067.00
# DELHI            63922.00
# DHARAMSHALA        466.00
# DHARWAD          18313.00
# DIMAPUR          27310.00
# DINDIGUL         23828.00
# ERNAKULAM        34544.00
# GURGAON           5915.00
# GUWAHATI         54809.50
# GWALIOR          13406.00
# HALDWANI          1440.00
# HISAR            23020.00
# HYDERABAD        46057.10
# INDORE           18230.00
# ITANAGAR         11716.00
# JABALPUR         11180.00
# ...                   ...
# MANGALORE          306.00
# MUMBAI           57918.10
# MYSORE             386.00
# ...
